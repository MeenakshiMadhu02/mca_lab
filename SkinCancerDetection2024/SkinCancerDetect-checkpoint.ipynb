# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# This function loads, preprocesses images from a specified directory.
# converting them to RGB format and associating them with their respective class labels.

labels = ['benign', 'malignant'] # Define your class labels
img_size = 64

datadir = r"C:\Users\HP\Desktop\Skin Cancer Detection\archivemb\train"

def get_training_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_path = os.path.join(path, img)
                img_arr = cv2.imread(img_path, cv2.IMREAD_COLOR)  # Read RGB images
                if img_arr is None:
                    print(f"Error reading image: {img_path}")
                    continue
                resized_arr = cv2.resize(img_arr, (img_size, img_size))  # Resize the image
                resized_arr = cv2.cvtColor(resized_arr, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
                data.append([resized_arr.astype('float32'), class_num])  # Convert to float32 for consistency
            except Exception as e:
                print(f"Error processing image {img_path}: {e}")
    return np.array(data, dtype=object)  # Use dtype=object if data types might be mixed

# Example usage
training_data = get_training_data(datadir)

# %%
# Applying get_training_data for the train and test sets

train = get_training_data(r'C:\Users\HP\Desktop\Skin Cancer Detection\archivemb\train')
test = get_training_data(r'C:\Users\HP\Desktop\Skin Cancer Detection\archivemb\test')

# %%
print('train count: ', len(train))
print('test count: ', len(test))
# Out:
# train count:  2637
# test count:  660

# %%
# Check for imbalance in training data (benign vs malignant cases)

train_benign = 0
for i in range(len(train)):
    if train[i][1] == 1:
        train_benign += 1
print('train benign: ', train_benign)
train_malignant = 0
for i in range(len(train)):
    if train[i][1] == 0:
        train_malignant += 1
print('train malignant: ', train_malignant)
print('train malignant - benign: ', train_malignant-train_benign)
# Out:
# train benign:  1197
# train malignant:  1440
# train malignant - benign:  243

# %%
print(train[0][0].shape)
# Out:
# (64, 64, 3)

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0]/255)
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'benign')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0]/255)
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'malignant')

# %%
from sklearn.model_selection import train_test_split

X = []
y = []

for feature, label in train:
    X.append(feature)
    y.append(label)

for feature, label in test:
    X.append(feature)
    y.append(label)


# resize data for deep learning
X = np.array(X).reshape(-1, img_size, img_size, 3)
y = np.array(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=90,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    shear_range=0.2,
    fill_mode='nearest'
)

# Fit the data generator on training data
datagen.fit(X_train)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import  accuracy_score, confusion_matrix
from keras import layers

model = Sequential()

model.add(Conv2D(64, (5, 5), input_shape=(img_size, img_size, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(BatchNormalization(axis=1))

model.add(Conv2D(128, (5, 5), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(BatchNormalization(axis=1))

model.add(Conv2D(256, (5, 5), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(BatchNormalization(axis=1))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(BatchNormalization(axis=1))

model.add(Conv2D(16, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
model.add(BatchNormalization(axis=1))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dense(64))
model.add(Activation('relu'))

# model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))


lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 64)          │           4,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 64)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 128)         │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 16, 16, 128)         │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 256)         │         819,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 8, 8, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 8, 8, 256)           │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 8, 8, 64)            │         147,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 4, 4, 64)            │              16 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 4, 4, 16)            │           9,232 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 4, 4, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 2, 2, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 2, 2, 16)            │               8 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          16,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_6 (Activation)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,219,401 (4.65 MB)
#  Trainable params: 1,219,277 (4.65 MB)
#  Non-trainable params: 124 (496.00 B)

# %%
history = model.fit(datagen.flow(X_train, y_train, batch_size=32), callbacks=[lr_reduction], validation_data=(X_test, y_test), epochs=30)

# Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print(f"Accuracy: {scores[1]*100:.2f}% \nError: {(1-scores[1])*100:.2f}%")
# Out:
# Epoch 1/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 717ms/step - accuracy: 0.6083 - loss: 0.6387 - val_accuracy: 0.5636 - val_loss: 0.9871 - learning_rate: 0.0010
# Epoch 2/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 688ms/step - accuracy: 0.7511 - loss: 0.5159 - val_accuracy: 0.4924 - val_loss: 0.7565 - learning_rate: 0.0010
# Epoch 3/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 665ms/step - accuracy: 0.7652 - loss: 0.4854 - val_accuracy: 0.6879 - val_loss: 0.5512 - learning_rate: 0.0010
# Epoch 4/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 677ms/step - accuracy: 0.7736 - loss: 0.4619 - val_accuracy: 0.7606 - val_loss: 0.5213 - learning_rate: 0.0010
# Epoch 5/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 681ms/step - accuracy: 0.7782 - loss: 0.4705 - val_accuracy: 0.6788 - val_loss: 0.9697 - learning_rate: 0.0010
# Epoch 6/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 689ms/step - accuracy: 0.7767 - loss: 0.4608 - val_accuracy: 0.7727 - val_loss: 0.4875 - learning_rate: 0.0010
# Epoch 7/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 58s 692ms/step - accuracy: 0.7684 - loss: 0.4761 - val_accuracy: 0.4545 - val_loss: 1.3497 - learning_rate: 0.0010
# Epoch 8/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 680ms/step - accuracy: 0.7727 - loss: 0.4700 - val_accuracy: 0.4636 - val_loss: 1.1112 - learning_rate: 0.0010
# Epoch 9/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 0.7742 - loss: 0.4764
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 682ms/step - accuracy: 0.7744 - loss: 0.4762 - val_accuracy: 0.4545 - val_loss: 1.4781 - learning_rate: 0.0010
# Epoch 10/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 673ms/step - accuracy: 0.7914 - loss: 0.4506 - val_accuracy: 0.4545 - val_loss: 0.9320 - learning_rate: 5.0000e-04
# Epoch 11/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 673ms/step - accuracy: 0.7882 - loss: 0.4344 - val_accuracy: 0.5576 - val_loss: 0.7288 - learning_rate: 5.0000e-04
# Epoch 12/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - accuracy: 0.8001 - loss: 0.4442
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 677ms/step - accuracy: 0.8000 - loss: 0.4442 - val_accuracy: 0.6455 - val_loss: 1.0478 - learning_rate: 5.0000e-04
# Epoch 13/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 670ms/step - accuracy: 0.8024 - loss: 0.4186 - val_accuracy: 0.4545 - val_loss: 1.3809 - learning_rate: 2.5000e-04
# Epoch 14/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 678ms/step - accuracy: 0.8043 - loss: 0.4081 - val_accuracy: 0.5439 - val_loss: 0.8905 - learning_rate: 2.5000e-04
# Epoch 15/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - accuracy: 0.7866 - loss: 0.4216
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1399s 17s/step - accuracy: 0.7868 - loss: 0.4214 - val_accuracy: 0.7348 - val_loss: 0.5412 - learning_rate: 2.5000e-04
# Epoch 16/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 687ms/step - accuracy: 0.8085 - loss: 0.3957 - val_accuracy: 0.7697 - val_loss: 0.4566 - learning_rate: 1.2500e-04
# Epoch 17/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 686ms/step - accuracy: 0.8055 - loss: 0.3988 - val_accuracy: 0.6197 - val_loss: 0.6677 - learning_rate: 1.2500e-04
# Epoch 18/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 671ms/step - accuracy: 0.8216 - loss: 0.3770 - val_accuracy: 0.7348 - val_loss: 0.5031 - learning_rate: 1.2500e-04
# Epoch 19/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 639ms/step - accuracy: 0.8116 - loss: 0.3903
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 689ms/step - accuracy: 0.8117 - loss: 0.3902 - val_accuracy: 0.7439 - val_loss: 0.5805 - learning_rate: 1.2500e-04
# Epoch 20/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 669ms/step - accuracy: 0.8148 - loss: 0.3649 - val_accuracy: 0.7712 - val_loss: 0.4658 - learning_rate: 6.2500e-05
# Epoch 21/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 675ms/step - accuracy: 0.8261 - loss: 0.3610 - val_accuracy: 0.7712 - val_loss: 0.4610 - learning_rate: 6.2500e-05
# Epoch 22/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 54s 649ms/step - accuracy: 0.8172 - loss: 0.3709 - val_accuracy: 0.8379 - val_loss: 0.3704 - learning_rate: 6.2500e-05
# Epoch 23/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 661ms/step - accuracy: 0.8303 - loss: 0.3566 - val_accuracy: 0.8273 - val_loss: 0.3712 - learning_rate: 6.2500e-05
# Epoch 24/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 55s 667ms/step - accuracy: 0.8294 - loss: 0.3545 - val_accuracy: 0.7803 - val_loss: 0.4746 - learning_rate: 6.2500e-05
# Epoch 25/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - accuracy: 0.8221 - loss: 0.3770
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 673ms/step - accuracy: 0.8221 - loss: 0.3770 - val_accuracy: 0.7894 - val_loss: 0.4374 - learning_rate: 6.2500e-05
# Epoch 26/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 672ms/step - accuracy: 0.8178 - loss: 0.3673 - val_accuracy: 0.7924 - val_loss: 0.4332 - learning_rate: 3.1250e-05
# Epoch 27/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 669ms/step - accuracy: 0.8227 - loss: 0.3604 - val_accuracy: 0.8227 - val_loss: 0.3686 - learning_rate: 3.1250e-05
# Epoch 28/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 57s 681ms/step - accuracy: 0.8138 - loss: 0.3719 - val_accuracy: 0.6864 - val_loss: 0.6021 - learning_rate: 3.1250e-05
# Epoch 29/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 674ms/step - accuracy: 0.8299 - loss: 0.3564 - val_accuracy: 0.7470 - val_loss: 0.5353 - learning_rate: 3.1250e-05
# Epoch 30/30
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - accuracy: 0.8170 - loss: 0.3656
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 56s 676ms/step - accuracy: 0.8172 - loss: 0.3655 - val_accuracy: 0.8348 - val_loss: 0.3717 - learning_rate: 3.1250e-05
# Accuracy: 83.48%
# Error: 16.52%

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
# loading the model
pretrained_model = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(img_size,img_size , 3))

# %%
# make the model layers un trainable to use the saved weights

for i in pretrained_model.layers:
    i.trainable = False

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import GlobalAveragePooling2D

# Set up EarlyStopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

# Set up ModelCheckpoint to save the best model based on validation loss
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss', mode='min', verbose=1)

# Build the model
model = Sequential()
model.add(pretrained_model)  # Add the pre-trained model
model.add(GlobalAveragePooling2D())  # Reduce dimensionality
model.add(BatchNormalization())  # Normalize activations
model.add(Dense(128, activation='relu'))  # Fully connected layer
model.add(Dropout(0.2))  # Dropout for regularization
model.add(Dense(32, activation='relu'))  # Fully connected layer
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model with both callbacks
history = model.fit(datagen.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping, model_checkpoint, lr_reduction],  # Add the EarlyStopping and ModelCheckpoint callbacks
                    epochs=25)

# Evaluate the best model
best_model_scores = model.evaluate(X_test, y_test, verbose=0)

# Print the accuracy and error
print(f"Best Model Accuracy: {best_model_scores[1] * 100:.2f}% \nError: {(1 - best_model_scores[1]) * 100:.2f}%")
# Out:
# Epoch 1/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.6532 - loss: 0.6215
# Epoch 1: val_loss improved from inf to 0.67721, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 59s 485ms/step - accuracy: 0.6536 - loss: 0.6210 - val_accuracy: 0.5561 - val_loss: 0.6772 - learning_rate: 0.0010
# Epoch 2/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.7501 - loss: 0.4992
# Epoch 2: val_loss improved from 0.67721 to 0.64642, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 397ms/step - accuracy: 0.7502 - loss: 0.4991 - val_accuracy: 0.5939 - val_loss: 0.6464 - learning_rate: 0.0010
# Epoch 3/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.7749 - loss: 0.4816
# Epoch 3: val_loss improved from 0.64642 to 0.62712, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 393ms/step - accuracy: 0.7749 - loss: 0.4816 - val_accuracy: 0.6167 - val_loss: 0.6271 - learning_rate: 0.0010
# Epoch 4/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.7623 - loss: 0.4737
# Epoch 4: val_loss improved from 0.62712 to 0.51778, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 391ms/step - accuracy: 0.7624 - loss: 0.4736 - val_accuracy: 0.7394 - val_loss: 0.5178 - learning_rate: 0.0010
# Epoch 5/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.7912 - loss: 0.4361
# Epoch 5: val_loss improved from 0.51778 to 0.46949, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 403ms/step - accuracy: 0.7912 - loss: 0.4362 - val_accuracy: 0.7909 - val_loss: 0.4695 - learning_rate: 0.0010
# Epoch 6/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.7901 - loss: 0.4429
# Epoch 6: val_loss improved from 0.46949 to 0.44631, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 396ms/step - accuracy: 0.7901 - loss: 0.4429 - val_accuracy: 0.7939 - val_loss: 0.4463 - learning_rate: 0.0010
# Epoch 7/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.7889 - loss: 0.4336
# Epoch 7: val_loss improved from 0.44631 to 0.42331, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 394ms/step - accuracy: 0.7889 - loss: 0.4336 - val_accuracy: 0.7970 - val_loss: 0.4233 - learning_rate: 0.0010
# Epoch 8/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.8023 - loss: 0.4061
# Epoch 8: val_loss improved from 0.42331 to 0.39655, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 397ms/step - accuracy: 0.8022 - loss: 0.4064 - val_accuracy: 0.8258 - val_loss: 0.3966 - learning_rate: 0.0010
# Epoch 9/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.8041 - loss: 0.4097
# Epoch 9: val_loss did not improve from 0.39655
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 362ms/step - accuracy: 0.8041 - loss: 0.4099 - val_accuracy: 0.8106 - val_loss: 0.3994 - learning_rate: 0.0010
# Epoch 10/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8026 - loss: 0.4186
# Epoch 10: val_loss improved from 0.39655 to 0.39495, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 396ms/step - accuracy: 0.8026 - loss: 0.4185 - val_accuracy: 0.8121 - val_loss: 0.3949 - learning_rate: 0.0010
# Epoch 11/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.7939 - loss: 0.4245
# Epoch 11: val_loss did not improve from 0.39495
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 363ms/step - accuracy: 0.7938 - loss: 0.4246 - val_accuracy: 0.7985 - val_loss: 0.4029 - learning_rate: 0.0010
# Epoch 12/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.7827 - loss: 0.4429
# Epoch 12: val_loss improved from 0.39495 to 0.38701, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 395ms/step - accuracy: 0.7828 - loss: 0.4428 - val_accuracy: 0.8182 - val_loss: 0.3870 - learning_rate: 0.0010
# Epoch 13/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8187 - loss: 0.3902
# Epoch 13: val_loss did not improve from 0.38701
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 365ms/step - accuracy: 0.8186 - loss: 0.3904 - val_accuracy: 0.8121 - val_loss: 0.3955 - learning_rate: 0.0010
# Epoch 14/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.7777 - loss: 0.4362
# Epoch 14: val_loss did not improve from 0.38701
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 365ms/step - accuracy: 0.7779 - loss: 0.4360 - val_accuracy: 0.8106 - val_loss: 0.3884 - learning_rate: 0.0010
# Epoch 15/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.7985 - loss: 0.4160
# Epoch 15: val_loss improved from 0.38701 to 0.38516, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 403ms/step - accuracy: 0.7985 - loss: 0.4159 - val_accuracy: 0.8167 - val_loss: 0.3852 - learning_rate: 0.0010
# Epoch 16/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8097 - loss: 0.4118
# Epoch 16: val_loss improved from 0.38516 to 0.38407, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 393ms/step - accuracy: 0.8096 - loss: 0.4118 - val_accuracy: 0.8318 - val_loss: 0.3841 - learning_rate: 0.0010
# Epoch 17/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.7976 - loss: 0.4124
# Epoch 17: val_loss did not improve from 0.38407
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 367ms/step - accuracy: 0.7975 - loss: 0.4124 - val_accuracy: 0.8227 - val_loss: 0.3940 - learning_rate: 0.0010
# Epoch 18/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.8088 - loss: 0.3999
# Epoch 18: val_loss improved from 0.38407 to 0.37117, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 416ms/step - accuracy: 0.8089 - loss: 0.3999 - val_accuracy: 0.8364 - val_loss: 0.3712 - learning_rate: 0.0010
# Epoch 19/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.7907 - loss: 0.4120
# Epoch 19: val_loss did not improve from 0.37117
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 368ms/step - accuracy: 0.7908 - loss: 0.4121 - val_accuracy: 0.8258 - val_loss: 0.3868 - learning_rate: 0.0010
# Epoch 20/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.7998 - loss: 0.4136
# Epoch 20: val_loss did not improve from 0.37117
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 364ms/step - accuracy: 0.7998 - loss: 0.4136 - val_accuracy: 0.8288 - val_loss: 0.3872 - learning_rate: 0.0010
# Epoch 21/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8009 - loss: 0.4212
# Epoch 21: val_loss did not improve from 0.37117
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 361ms/step - accuracy: 0.8010 - loss: 0.4210 - val_accuracy: 0.8227 - val_loss: 0.3774 - learning_rate: 0.0010
# Epoch 22/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8057 - loss: 0.4150
# Epoch 22: val_loss did not improve from 0.37117
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 31s 371ms/step - accuracy: 0.8057 - loss: 0.4149 - val_accuracy: 0.8182 - val_loss: 0.3751 - learning_rate: 5.0000e-04
# Epoch 23/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8110 - loss: 0.4052
# Epoch 23: val_loss did not improve from 0.37117
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 364ms/step - accuracy: 0.8110 - loss: 0.4052 - val_accuracy: 0.8227 - val_loss: 0.3731 - learning_rate: 5.0000e-04
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Best Model Accuracy: 83.64%
# Error: 16.36%

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))

# Set up EarlyStopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)

# Set up ModelCheckpoint to save the best model based on validation loss
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss', mode='min', verbose=1)

for i in base_model.layers[:15]:
    i.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size=32, 
                    callbacks=[early_stopping, model_checkpoint, lr_reduction],
                    validation_data=(X_test, y_test), epochs=25)

# Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print(f"Accuracy: {scores[1]*100:.2f}% \nError: {(1-scores[1])*100:.2f}%")
# Out:
# Epoch 1/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.5770 - loss: 0.6573
# Epoch 1: val_loss improved from inf to 0.41685, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 82s 894ms/step - accuracy: 0.5782 - loss: 0.6562 - val_accuracy: 0.8227 - val_loss: 0.4168 - learning_rate: 0.0010
# Epoch 2/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.8165 - loss: 0.3834
# Epoch 2: val_loss improved from 0.41685 to 0.40669, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 72s 865ms/step - accuracy: 0.8166 - loss: 0.3833 - val_accuracy: 0.8303 - val_loss: 0.4067 - learning_rate: 0.0010
# Epoch 3/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.8375 - loss: 0.3511
# Epoch 3: val_loss did not improve from 0.40669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 838ms/step - accuracy: 0.8375 - loss: 0.3509 - val_accuracy: 0.8364 - val_loss: 0.4117 - learning_rate: 0.0010
# Epoch 4/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.8767 - loss: 0.2919
# Epoch 4: val_loss did not improve from 0.40669
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 845ms/step - accuracy: 0.8767 - loss: 0.2918 - val_accuracy: 0.7879 - val_loss: 0.5076 - learning_rate: 0.0010
# Epoch 5/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.8723 - loss: 0.3454
# Epoch 5: val_loss improved from 0.40669 to 0.34375, saving model to best_model.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 72s 868ms/step - accuracy: 0.8724 - loss: 0.3447 - val_accuracy: 0.8424 - val_loss: 0.3438 - learning_rate: 0.0010
# Epoch 6/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9007 - loss: 0.2268
# Epoch 6: val_loss did not improve from 0.34375
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 838ms/step - accuracy: 0.9005 - loss: 0.2269 - val_accuracy: 0.8364 - val_loss: 0.3618 - learning_rate: 0.0010
# Epoch 7/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 699ms/step - accuracy: 0.8877 - loss: 0.2350
# Epoch 7: val_loss did not improve from 0.34375
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 837ms/step - accuracy: 0.8879 - loss: 0.2349 - val_accuracy: 0.8409 - val_loss: 0.3693 - learning_rate: 0.0010
# Epoch 8/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9062 - loss: 0.2092
# Epoch 8: val_loss did not improve from 0.34375
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 843ms/step - accuracy: 0.9063 - loss: 0.2093 - val_accuracy: 0.8500 - val_loss: 0.4821 - learning_rate: 0.0010
# Epoch 9/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9191 - loss: 0.2026
# Epoch 9: val_loss did not improve from 0.34375
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 841ms/step - accuracy: 0.9192 - loss: 0.2023 - val_accuracy: 0.8500 - val_loss: 0.5772 - learning_rate: 5.0000e-04
# Epoch 10/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.9466 - loss: 0.1333
# Epoch 10: val_loss did not improve from 0.34375
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 846ms/step - accuracy: 0.9465 - loss: 0.1335 - val_accuracy: 0.8606 - val_loss: 0.4462 - learning_rate: 5.0000e-04
# Epoch 11/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9528 - loss: 0.1229
# Epoch 11: val_loss did not improve from 0.34375
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 837ms/step - accuracy: 0.9528 - loss: 0.1229 - val_accuracy: 0.8273 - val_loss: 0.4801 - learning_rate: 5.0000e-04
# Epoch 12/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.9551 - loss: 0.0987
# Epoch 12: val_loss did not improve from 0.34375
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 845ms/step - accuracy: 0.9551 - loss: 0.0987 - val_accuracy: 0.8545 - val_loss: 0.6065 - learning_rate: 2.5000e-04
# Epoch 13/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9651 - loss: 0.0887
# Epoch 13: val_loss did not improve from 0.34375
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 69s 835ms/step - accuracy: 0.9651 - loss: 0.0886 - val_accuracy: 0.8470 - val_loss: 0.6912 - learning_rate: 2.5000e-04
# Epoch 14/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.9703 - loss: 0.0672
# Epoch 14: val_loss did not improve from 0.34375
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 70s 842ms/step - accuracy: 0.9703 - loss: 0.0672 - val_accuracy: 0.8530 - val_loss: 0.8860 - learning_rate: 2.5000e-04
# Epoch 15/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.9720 - loss: 0.0654
# Epoch 15: val_loss did not improve from 0.34375
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 81s 843ms/step - accuracy: 0.9720 - loss: 0.0653 - val_accuracy: 0.8500 - val_loss: 0.8398 - learning_rate: 1.2500e-04
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Accuracy: 84.24%
# Error: 15.76%

# %%
# Define needed variables
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
# Save the model as an HDF5 file
model.save('skin_model.keras')

# %%
import shutil

# Move the HDF5 file to the desired download location (e.g., your Downloads folder)
shutil.move('skin_model.keras', r'C:\Users\HP\Desktop\Skin Cancer Detection')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[24], line 4
#       1 import shutil
#       3 # Move the HDF5 file to the desired download location (e.g., your Downloads folder)
# ----> 4 shutil.move('skin_model.keras', r'C:\Users\HP\Desktop\Skin Cancer Detection')
#
# File C:\Python311\Lib\shutil.py:823, in move(src, dst, copy_function)
#     820     real_dst = os.path.join(dst, _basename(src))
#     822     if os.path.exists(real_dst):
# --> 823         raise Error("Destination path '%s' already exists" % real_dst)
#     824 try:
#     825     os.rename(src, real_dst)
#
# Error: Destination path 'C:\Users\HP\Desktop\Skin Cancer Detection\skin_model.keras' already exists
